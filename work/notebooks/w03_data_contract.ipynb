# %% [markdown]
# # ML-04 — Search Intelligence Data Contract
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/MansiNegi281/CapstoneFlyrankAI/blob/main/work/notebooks/w03_data_contract.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. Unit of analysis + time window
#
# *One row = one what, over which dates? State it, then verify it below.*
#
# Unit of analysis : One row in the data represents a content page or article. Each content page has an identifier called content_id.
#
# Time Window : refers to the period used to collect data. Features are created using search and analytics data from 30 days and past 90 days.

# %%
print("Rows:", df.shape[0])
print("Columns:", df.shape[1])
df[['content_id',
    'impressions_90d',
    'sessions_90d',
    'content_age_days']].head()

# %% [markdown]
# ## 2. Fields: feature / label / context / excluded
#
# *Sort every field you plan to touch into these four buckets. Excluded needs a why.*
#
# Feature : impressions_90d,clicks_90d,sessions_90d,ctr,avg_position,content_age_days,days_since_last_update,search_volume,competition,cpc,engagement_rate,scroll_rate
#
# Label : trend_pct,trend_direction
#
# Context : content_id,client_id,content_type,provider_used,model_used
#
# Excluded : content_id - identifier only,client_id - identifier only

# %%
print(df.columns.tolist())

# %% [markdown]
# ## 3. Verify it with queries (grain, counts, missing values, windows)
#
# *Every claim above gets a query cell here. A contract claim without a query next to it is a guess.*
#
# The dataset has a lot of information with 30,000 content pages. There are some missing values in the metadata fields like the search volume the cost per click and the fields that have to do with content generation.. The main performance metrics for the dataset are all there.

# %%
print("Dataset shape:", df.shape)
print("\nMissing values:")
print(df.isnull().sum().sort_values(ascending=False).head(15))
print("\nUnique content IDs:")
print(df['content_id'].nunique())
print("\nTrend distribution:")
print(df['trend_direction'].value_counts())

# %% [markdown]
# ## 4. Data limits
#
# *What can this data never tell you? Unbalanced history, GSC-only early rows, window overlaps.*
#
# This data is not able to give consistent historical comparisons because the histories of the clients are not balanced. Some of the rows might have only GSC data and not have GA4 engagement metrics, which means some performance measures are not complete. It also cannot promise results that're free from bias when the feature windows and target windows overlap because this can cause information leakage.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
